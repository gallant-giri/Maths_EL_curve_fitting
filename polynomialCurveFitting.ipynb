# %%
import numpy as np
import matplotlib.pyplot as plt

n = int(input("Enter the number of data points: "))
x = []
y = []
for i in range(n):
    x.append(float(input(f"Enter x[{i+1}]: ")))
    y.append(float(input(f"Enter y[{i+1}]: ")))

x = np.array(x)
y = np.array(y)

degree = int(input("Enter the degree of the polynomial: "))
coefficients = np.polyfit(x, y, degree)
polynomial = np.poly1d(coefficients)

x_fit = np.linspace(min(x), max(x), 100)
y_fit = polynomial(x_fit)

plt.scatter(x, y, color='red', label='Original Data')
plt.plot(x_fit, y_fit, color='blue', label=f'Polynomial Fit (Degree {degree})')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Polynomial Curve Fitting")
plt.legend()
plt.show()

print("Polynomial equation:")
print(polynomial)
# Out:
# C:\Users\rajes\AppData\Local\Temp\ipykernel_16544\844436124.py:15: RankWarning: Polyfit may be poorly conditioned
#   coefficients = np.polyfit(x, y, degree)
# Polynomial equation:
#             8             7             6             5             4
# -7.209e-10 x + 1.686e-09 x + 1.907e-07 x + 4.798e-06 x + 8.307e-05 x
#               3            2
#  + 0.0008162 x - 0.009759 x - 0.4773 x + 7.486
